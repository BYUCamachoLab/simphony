# %%
import gdsfactory as gf

# %%
c = gf.Component()
mzi1 = c << gf.components.mzi_phase_shifter_top_heater_metal(delta_length=5, length_y=1, length_x=50, bend='bend_euler', straight='straight', straight_x_top='straight_heater_metal', splitter='mmi1x2', with_splitter=True, port_e1_splitter='o2', port_e0_splitter='o3', port_e1_combiner='o2', port_e0_combiner='o3', port1='o1', port2='o2', nbends=2, cross_section='strip', mirror_bot=False, add_optical_ports_arms=False, min_length=0.01, auto_rename_ports=True).copy()
# mzi2 = c << gf.components.mzi_phase_shifter_top_heater_metal(delta_length=10, length_y=1, length_x=80, bend='bend_euler', straight='straight', straight_x_top='straight_heater_metal', splitter='mmi1x2', with_splitter=True, port_e1_splitter='o2', port_e0_splitter='o3', port_e1_combiner='o2', port_e0_combiner='o3', port1='o1', port2='o2', nbends=2, cross_section='strip', mirror_bot=False, add_optical_ports_arms=False, min_length=0.01, auto_rename_ports=True).copy()
coupler_source1 = c << gf.components.grating_coupler_array(grating_coupler='grating_coupler_elliptical',n = 1).copy()
coupler_source2 = c << gf.components.grating_coupler_array(grating_coupler='grating_coupler_elliptical',n = 1).copy()
coupler_source3 = c << gf.components.grating_coupler_array(grating_coupler='grating_coupler_elliptical',n = 1).copy()
coupler_source4 = c << gf.components.grating_coupler_array(grating_coupler='grating_coupler_elliptical',n = 1).copy()
coupler_source5 = c << gf.components.grating_coupler_array(grating_coupler='grating_coupler_elliptical',n = 1).copy()
coupler_source6 = c << gf.components.grating_coupler_array(grating_coupler='grating_coupler_elliptical',n = 1).copy()
coupler_source7 = c << gf.components.grating_coupler_array(grating_coupler='grating_coupler_elliptical',n = 1).copy()
coupler_source8 = c << gf.components.grating_coupler_array(grating_coupler='grating_coupler_elliptical',n = 1).copy()
coupler_source9 = c << gf.components.grating_coupler_array(grating_coupler='grating_coupler_elliptical',n = 1).copy()
spacing_y = 100
y_branch2 = c << gf.components.splitter_tree(coupler='mmi1x2', noutputs=8, spacing=(30, spacing_y), bend_s='bend_s', cross_section='strip').copy()
y_branch3 = c << gf.components.splitter_tree(coupler='mmi1x2', noutputs=2, spacing=(20, 100), bend_s='bend_s', cross_section='strip').copy()

# delay_line = c << gf.components.spiral_racetrack_fixed_length(length=250, in_out_port_spacing=75, n_straight_sections=0, min_spacing=5, bend='bend_circular', bend_s='bend_s', cross_section='strip').copy()
delay_line2 = c << gf.components.spiral_racetrack_fixed_length(length=250, in_out_port_spacing=100, n_straight_sections=2, min_spacing=5, bend='bend_circular', bend_s='bend_s', cross_section='strip').copy()
delay_line3 = c << gf.components.spiral_racetrack_fixed_length(length=400, in_out_port_spacing=150, n_straight_sections=2, min_spacing=5, bend='bend_circular', bend_s='bend_s', cross_section='strip').copy()
delay_line4 = c << gf.components.spiral_racetrack_fixed_length(length=1000, in_out_port_spacing=150, n_straight_sections=6, min_spacing=5, bend='bend_circular', bend_s='bend_s', cross_section='strip').copy()

straight1 = c << gf.components.straight(length=168.5, cross_section='strip').copy()
straight2 = c << gf.components.straight(length=170, cross_section='strip').copy()
straight3 = c << gf.components.straight(length=58.5, cross_section='strip').copy()
straight4 = c << gf.components.straight(length=10, cross_section='strip').copy()
straight5 = c << gf.components.straight(length=1, cross_section='strip').copy()
terminal = c << gf.components.terminator_spiral(separation=3, width_tip=0.2, number_of_loops=1, npoints=1000, cross_section='strip').copy()
bend3 = c << gf.components.bend_s(size=(255, 175), npoints=99, cross_section='strip', allow_min_radius_violation=False).copy()
dx = 30
length_couple = 25
dy = spacing_y//2
coupler1 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler2 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler3 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler4 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler5 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler6 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler7 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler8 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler9 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler10 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler11 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler12 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler13 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler14 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler15 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler16 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler17 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler18 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler19 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler20 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler21 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler22 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler23 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler24 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
coupler25 = c << gf.components.coupler(gap=2.5, length=length_couple, dy=dy, dx=dx, cross_section='strip', allow_min_radius_violation=False, bend='bend_s').copy()
length_wg = dx*2 + length_couple
straight6 = c << gf.components.straight(length=length_wg, cross_section='strip').copy()
straight7 = c << gf.components.straight(length=length_wg, cross_section='strip').copy()
straight8 = c << gf.components.straight(length=length_wg, cross_section='strip').copy()
straight9 = c << gf.components.straight(length=length_wg, cross_section='strip').copy()
straight10 = c << gf.components.straight(length=length_wg, cross_section='strip').copy()
straight11 = c << gf.components.straight(length=length_wg, cross_section='strip').copy()


coupler_source1.rotate(-90)
y_branch3.connect("o1_0_0", coupler_source1.ports["o0"])
mzi1.connect("o1", y_branch3.ports["o2_0_2"])
y_branch2.connect("o1_0_0", mzi1.ports["o2"])
bend3.connect("o1", y_branch3.ports["o2_0_1"])
# delay_line.connect("o1", y_branch2.ports["o2_2_7"])
delay_line2.connect("o1", y_branch2.ports["o2_2_8"])
delay_line3.connect("o1", y_branch2.ports["o2_2_5"])
delay_line4.connect("o1", y_branch2.ports["o2_2_1"])
straight1.connect("o1", y_branch2.ports["o2_2_7"])
straight2.connect("o1", bend3.ports["o2"])
straight3.connect("o1", delay_line2.ports["o2"])
straight4.connect("o1", delay_line3.ports["o2"])
straight5.connect("o1", delay_line4.ports["o2"])

coupler1.connect("o2", straight2.ports["o2"])
coupler2.connect("o2", straight3.ports["o2"])
coupler3.connect("o1", straight5.ports["o2"])
terminal.connect("o1", y_branch2.ports["o2_2_2"])
coupler4.connect("o2", coupler1.ports["o4"])
coupler5.connect("o2", coupler2.ports["o4"])
coupler6.connect("o3", coupler5.ports["o1"])
coupler7.connect("o2", coupler6.ports["o4"])

straight6.connect("o1", coupler1.ports["o3"])
straight7.connect("o1", coupler3.ports["o4"])

coupler8.connect("o2", straight6.ports["o2"])
coupler9.connect("o2", coupler4.ports["o4"])
coupler10.connect("o2", coupler5.ports["o4"])
coupler11.connect("o2", coupler7.ports["o4"])

coupler12.connect("o2", coupler8.ports["o4"])
coupler13.connect("o2", coupler9.ports["o4"])
coupler14.connect("o2", coupler10.ports["o4"])
straight8.connect("o1", coupler8.ports["o3"])
straight9.connect("o1", coupler11.ports["o4"])

coupler15.connect("o2", straight8.ports["o2"])
coupler16.connect("o2", coupler12.ports["o4"])
coupler17.connect("o2", coupler13.ports["o4"])
coupler18.connect("o2", coupler14.ports["o4"])

coupler19.connect("o2", coupler15.ports["o4"])
coupler20.connect("o2", coupler16.ports["o4"])
coupler21.connect("o2", coupler17.ports["o4"])
straight10.connect("o1", coupler15.ports["o3"])
straight11.connect("o1", coupler18.ports["o4"])

coupler22.connect("o2", straight10.ports["o2"])
coupler23.connect("o2", coupler19.ports["o4"])
coupler24.connect("o2", coupler20.ports["o4"])
coupler25.connect("o2", coupler21.ports["o4"])

coupler_source2.connect("o0", coupler22.ports["o3"])
coupler_source3.connect("o0", coupler22.ports["o4"])
coupler_source4.connect("o0", coupler23.ports["o3"])
coupler_source5.connect("o0", coupler23.ports["o4"])
coupler_source6.connect("o0", coupler24.ports["o3"])
coupler_source7.connect("o0", coupler24.ports["o4"])
coupler_source8.connect("o0", coupler25.ports["o3"])
coupler_source9.connect("o0", coupler25.ports["o4"])
c.plot()
c.write_gds("reservoir.gds")
# Out:
# WindowsPath('reservoir.gds')

# %%
new_component = gf.Component()
coupler_source1 = new_component << gf.components.grating_coupler_array(grating_coupler='grating_coupler_elliptical',n = 1).copy()
new_component.write_gds("input_coupler.gds")
# Out:
# WindowsPath('input_coupler.gds')

# %%
delay_component = gf.Component()
delay_line = delay_component << gf.components.spiral(length=20, bend='bend_euler', straight='straight', cross_section='strip', spacing=3, n_loops=4).copy()
delay_component.write_gds("delay_line.gds")
# Out:
# WindowsPath('delay_line.gds')
